# %% [markdown]
# # Noise reduction
#
# This notebook shows how to use the functions developed for noise reduction.

# %% [markdown]
# ## 1. Imports
#
# First we import the library of functions.

# %%
from utilities_store import *

# %% [markdown]
# ## 2. Obtain spectrogram of noisy signal
#
# First we obtain the spectrogram of the noisy signal from which we want to reduce the noise.

# %%
noisy_spectrogram, noisy_signal = get_spectrogram('nine_mono_noisy.wav', N = 500, step_size = 250, 
                                                  power_threshold = 1e-9, amp_threshold = 1e-8)
# Out:
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/fpt.py:224: RuntimeWarning: overflow encountered in power
#   Z = np.power(self.zs.reshape(-1, 1), exponent)
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/fpt.py:234: RuntimeWarning: invalid value encountered in divide
#   d = np.divide(Z @ ps[1:].reshape(-1, 1),
# Progress: 0.00%
# Progress: 0.76%
# Progress: 1.53%
# Progress: 2.29%
# Progress: 3.06%
# Progress: 3.82%
# Progress: 4.59%
# Progress: 5.35%
# Progress: 6.11%
# Progress: 6.88%
# Progress: 7.64%
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/resonance.py:216: RuntimeWarning: overflow encountered in cdouble_scalars
#   d_ = self.d * self.z ** (self.N - 1)
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/resonance.py:216: RuntimeWarning: invalid value encountered in cdouble_scalars
#   d_ = self.d * self.z ** (self.N - 1)
# Progress: 8.41%
# Progress: 9.17%
# Progress: 9.94%
# Progress: 10.70%
# Progress: 11.46%
# Progress: 12.23%
# Progress: 12.99%
# Progress: 13.76%
# Progress: 14.52%
# Progress: 15.29%
# Progress: 16.05%
# Progress: 16.81%
# Progress: 17.58%
# Progress: 18.34%
# Progress: 19.11%
# Progress: 19.87%
# Progress: 20.64%
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/resonance.py:266: RuntimeWarning: invalid value encountered in cdouble_scalars
#   return replace(self, d=self.d * self.z ** offset)
# Progress: 21.40%
# Progress: 22.16%
# Progress: 22.93%
# Progress: 23.69%
# Progress: 24.46%
# Progress: 25.22%
# Progress: 25.99%
# Progress: 26.75%
# Progress: 27.51%
# Progress: 28.28%
# Progress: 29.04%
# Progress: 29.81%
# Progress: 30.57%
# Progress: 31.34%
# Progress: 32.10%
# Progress: 32.86%
# Progress: 33.63%
# Progress: 34.39%
# Progress: 35.16%
# Progress: 35.92%
# Progress: 36.69%
# Progress: 37.45%
# Progress: 38.21%
# Progress: 38.98%
# Progress: 39.74%
# Progress: 40.51%
# Progress: 41.27%
# Progress: 42.04%
# Progress: 42.80%
# Progress: 43.56%
# Progress: 44.33%
# Progress: 45.09%
# Progress: 45.86%
# Progress: 46.62%
# Progress: 47.39%
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/fpt.py:234: RuntimeWarning: invalid value encountered in matmul
#   d = np.divide(Z @ ps[1:].reshape(-1, 1),
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/fpt.py:235: RuntimeWarning: overflow encountered in matmul
#   Z @ (qs[1:] * i).reshape(-1, 1))
# /Users/nastysushi/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/fpt.py:235: RuntimeWarning: invalid value encountered in matmul
#   Z @ (qs[1:] * i).reshape(-1, 1))
# Progress: 48.15%
# Progress: 48.91%
# Progress: 49.68%
# Progress: 50.44%
# Progress: 51.21%
# Progress: 51.97%
# Progress: 52.74%
# Progress: 53.50%
# Progress: 54.26%
# Progress: 55.03%
# Progress: 55.79%
# Progress: 56.56%
# Progress: 57.32%
# Progress: 58.09%
# Progress: 58.85%
# Progress: 59.61%
# Progress: 60.38%
# Progress: 61.14%
# Progress: 61.91%
# Progress: 62.67%
# Progress: 63.44%
# Progress: 64.20%
# Progress: 64.96%
# Progress: 65.73%
# Progress: 66.49%
# Progress: 67.26%
# Progress: 68.02%
# Progress: 68.79%
# Progress: 69.55%
# Progress: 70.31%
# Progress: 71.08%
# Progress: 71.84%
# Progress: 72.61%
# Progress: 73.37%
# Progress: 74.14%
# Progress: 74.90%
# Progress: 75.66%
# Progress: 76.43%
# Progress: 77.19%
# Progress: 77.96%
# Progress: 78.72%
# Progress: 79.49%
# Progress: 80.25%
# Progress: 81.01%
# Progress: 81.78%
# Progress: 82.54%
# Progress: 83.31%
# Progress: 84.07%
# Progress: 84.84%
# Progress: 85.60%
# Progress: 86.37%
# Progress: 87.13%
# Progress: 87.89%
# Progress: 88.66%
# Progress: 89.42%
# Progress: 90.19%
# Progress: 90.95%
# Progress: 91.72%
# Progress: 92.48%
# Progress: 93.24%
# Progress: 94.01%
# Progress: 94.77%
# Progress: 95.54%
# Progress: 96.30%
# Progress: 97.07%
# Progress: 97.83%
# Progress: 98.59%
# Progress: 99.36%

# %% [markdown]
# Plot the resonance spectrogram

# %%
plot_spectrogram(noisy_spectrogram, signal = None, min_freq = 0, max_freq = 5000, scale=500)

# %% [markdown]
# ## 3. Noise reduction
#
# The denoising function consists of three different denoising algorithms:
#
#     - Density: Low density resonances are attenuated
#     - Power: Low power resonances are filtered
#     - Dynamic resonances: Filter resonances based on their dynamic resonance properties
#
# We can select the main parameters of each filter in the denoise function used below:

# %%
denoised_spectrogram = denoise(noisy_spectrogram, density_factor = 50, power_factor = 0.1, 
                               min_overlap = None, min_length = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 denoised_spectrogram = denoise(noisy_spectrogram, density_factor = 50, power_factor = 0.1,
#       2                                min_overlap = None, min_length = None)
#
# File ~/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/utilities_store.py:2091, in denoise(spectrogram, density_factor, power_factor, min_overlap, min_length)
#    2065 """Function to denoise a spectrogram based its dynamic resonances.
#    2066
#    2067 Parameters
#    (...)
#    2087     Denoised resonance spectrogram
#    2088 """
#    2090 if density_factor is not None:
# -> 2091     spectrogram = denoise_by_density(spectrogram, slices_overlap=7, freq_overlap=250, density_factor=density_factor)
#    2093 if power_factor is not None:
#    2094     spectrogram = denoise_by_power(spectrogram, power_factor=power_factor)
#
# File ~/Mirror/_MULTIMEDIA/THESIS/thesis/github/fpt/utilities_store.py:2022, in denoise_by_density(spectrogram, slices_overlap, freq_overlap, density_threshold, density_factor)
#    2015 new_elements = [
#    2016     Resonance(res.d if density > density_threshold else res.d * (np.exp(- 2 * (1 - density / density_threshold))),
#    2017               res.w, res.z, res.N, res.sample_rate)
#    2018     for res, density in zip(spectrogram.elements, density_spectrogram)]
#    2020 ids = [hash(res) for res in new_elements]
# -> 2022 return ResonanceSpectrogram(np.array(ids), np.array(spectrogram.onsets))
#
# NameError: name 'ResonanceSpectrogram' is not defined

# %% [markdown]
# Plot the denoised resonace spectrogram

# %%
plot_spectrogram(denoised_spectrogram, signal = None, min_freq = 0, max_freq = 5000, scale=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_spectrogram(denoised_spectrogram, signal = None, min_freq = 0, max_freq = 5000, scale=500)
#
# NameError: name 'denoised_spectrogram' is not defined

# %% [markdown]
# Plot the noisy and denoised signal in time:

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.plot(noisy_signal/np.max(np.abs(noisy_signal)), label = "Noisy signal")
plt.plot(denoised_spectrogram.reconstruction.real, label = "Denoised signal")
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# Reproduce the audio of the noisy and denoised signals

# %% [markdown]
# Noisy signal:

# %%
ipd.Audio(data = noisy_signal, rate = noisy_spectrogram.sample_rate[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Denoised signal:

# %%
ipd.Audio(data = denoised_spectrogram.reconstruction.real, rate = noisy_spectrogram.sample_rate[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
write("nine-denoised.wav", noisy_spectrogram.sample_rate[0], denoised_spectrogram.reconstruction.real)
